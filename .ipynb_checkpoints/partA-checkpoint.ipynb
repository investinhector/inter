# %%
# General syntax to import a library but no functions: 
##import (library) as (give the library a nickname/alias)
import matplotlib.pyplot as plt
import pandas as pd #this is how I usually import pandas
import sys #only needed to determine Python version number
import matplotlib #only needed to determine Matplotlib version number
import glob 
import os

# Enable inline plotting
# %matplotlib inline
print('Python version ' + sys.version)
print('Pandas version ' + pd.__version__)
print('Matplotlib version ' + matplotlib.__version__)

#PX_OPEN,PX_HIGH, PX_LOW, PX_LAST, PX_VOLUME, 

#BELOW IS SUCCESSFUL CONCATENTATION
# outdir = r'C:\Users\lucy1\Documents\neco\new\files'
# df_final = pd.DataFrame(columns=['ticker','PX_OPEN', 'PX_HIGH', 'PX_LOW', 'PX_LAST', 'PX_VOLUME', 'date']) # creates an empty df with the desired structure
# for root, dirs, filenames in os.walk(outdir):
#     for f in filenames:
#         if f.endswith('.csv'):
#             df_temp = pd.read_csv(root + '\\' + f)
# #             df_temp ['filename'] = os.path.basename(csv)
#             df_final = pd.concat([df_final, df_temp])
            
# df_final.to_csv('concatenated.csv',index=False,header=True) #export to csv

#BELOW CREATES fills the date column with the names of the csv files
# outdir = r'C:\Users\lucy1\Documents\neco\new\files'
# df_final = pd.DataFrame(columns=['ticker','PX_OPEN', 'PX_HIGH', 'PX_LOW', 'PX_LAST', 'PX_VOLUME']) # creates an empty df with the desired structure
# for root, dirs, filenames in os.walk(outdir):
#     for f in filenames:
#         if f.endswith('.csv'):
#             df_temp = pd.read_csv(root + '\\' + f)
#             df_temp ['date'] = os.path.basename(root + '\\' + f)
#             df_final = pd.concat([df_final, df_temp])
            
# df_final.to_csv('concatenated.csv',index=False,header=True) #export to csv

#BELOW try to get the folder names
outdir = r'C:\Users\lucy1\Documents\neco\new\files'
df_final = pd.DataFrame(columns=['ticker','PX_OPEN', 'PX_HIGH', 'PX_LOW', 'PX_LAST', 'PX_VOLUME', 'date']) # creates an empty df with the desired structure
for root, dirs, filenames in os.walk(outdir):
    for f in filenames:
        if f.endswith('.csv'):
            df_temp = pd.read_csv(root + '\\' + f)
            df_temp ['date'] = os.path.basename(root + '\\' + f)
            df_final = pd.concat([df_final, df_temp])
    
    directory_list = list()
    for name in dirs:
        directory_list.append(os.path.join(root, name))
    
    print (directory_list)

# df_final.assign(date=directory_list)
print (df_final)
            
df_final.to_csv('concatenated2.csv',index=False,header=True) #export to csv
# Out:
# Python version 3.7.4 (default, Aug  9 2019, 18:34:13) [MSC v.1915 64 bit (AMD64)]
# Pandas version 0.25.1
# Matplotlib version 3.1.1
# ...

# %%
df_final
